# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullahkrs/e-Portfolio-Machine-Learning-January-2025/blob/main/Polynomial_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🔁 Polynomial Regression using cars.csv
#
# This notebook demonstrates **Polynomial Regression** using the `cars.csv` dataset to model the non-linear relationship between a car’s **weight** and its **CO2 emissions**.
#
# ## 📌 Description
# - **Feature (x)**: `Weight` (kg)
# - **Target (y)**: `CO2` (g/km)
# - **Method**: `numpy.polyfit` with degree 2 (quadratic fit)
#
# ## 📈 Objective
# To explore whether a non-linear curve fits the data better than a simple straight-line regression.
#
# ## 🧪 Learning Outcomes
# - Understand the concept and application of polynomial regression
# - Visualize complex relationships in data
# - Compare curve fitting with linear regression
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
import io

# Upload CSV file
uploaded = files.upload()
df = pd.read_csv(io.BytesIO(uploaded[list(uploaded.keys())[0]]))

# Use Weight and CO2 for polynomial regression
x = df['Weight']
y = df['CO2']

# Fit a 2nd-degree polynomial model
mymodel = np.poly1d(np.polyfit(x, y, 2))

# Create line for plotting
myline = np.linspace(x.min(), x.max(), 100)

# Plot original points and polynomial regression curve
plt.scatter(x, y, label='Actual Data')
plt.plot(myline, mymodel(myline), color='red', label='Polynomial Regression (Degree 2)')
plt.xlabel("Car Weight (kg)")
plt.ylabel("CO2 Emissions (g/km)")
plt.title("Polynomial Regression: Weight vs CO2")
plt.grid(True)
plt.legend()
plt.show()
# Out:
#      <input type="file" id="files-14727d9e-a9f2-4acb-8ba3-5b05bdc2b8cd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-14727d9e-a9f2-4acb-8ba3-5b05bdc2b8cd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

#NumPy has a method that lets us make a polynomial model
mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

#specify how the line will display, we start at position 1, and end at position 22
myline = numpy.linspace(1, 22, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %% [markdown]
# It is important to know how well the relationship between the values of the x- and y-axis is, if there are no relationship the polynomial regression can not be used to predict anything.
#
# The relationship is measured with a value called the r-squared.
#
# The r-squared value ranges from 0 to 1, where 0 means no relationship, and 1 means 100% related

# %%
from sklearn.metrics import r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

print(r2_score(y, mymodel(x)))
# Out:
# 0.9432150416451026

# %% [markdown]
# ## Predict Future Values

# %% [markdown]
# Let us try to predict the speed of a car that passes the tollbooth at around 17 P.M

# %%
from sklearn.metrics import r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

speed = mymodel(17)
print(speed)
# Out:
# 88.87331269698001
